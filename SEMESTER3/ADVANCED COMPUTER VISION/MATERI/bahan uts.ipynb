# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 8.3 MB/s eta 0:00:01
#    --------------- ------------------------ 3.1/8.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 7.7 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 7.5 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# ...

# %%
import tensorflow as tf
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
img = image.load_img('C:\\Users\\ASEP RIDWAN\\Pictures\\photo.JPG')
plt.imshow(img)

# %%
train = ImageDataGenerator(rescale = 1/255)
validation = ImageDataGenerator(rescale = 1/255)
train_dataset = train.flow_from_directory('/content/custom image tensorflow/train/',
                                          target_size = (200,200),
                                          batch_size=3,
                                          class_mode='binary')
validation_dataset = train.flow_from_directory('/content/custom image tensorflow/validation/',
                                          target_size = (200,200),
                                          batch_size=3,
                                          class_mode='binary')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 train = ImageDataGenerator(rescale = 1/255)
#       2 validation = ImageDataGenerator(rescale = 1/255)
# ----> 3 train_dataset = train.flow_from_directory('/content/custom image tensorflow/train/',
#       4                                           target_size = (200,200),
#       5                                           batch_size=3,
#       6                                           class_mode='binary')
#       7 validation_dataset = train.flow_from_directory('/content/custom image tensorflow/validation/',
#       8                                           target_size = (200,200),
#       9                                           batch_size=3,
#      10                                           class_mode='binary')
#
# ...
